# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
import pandas as pd

dataset = {"height": [2, 3, 4, 5], "weight": [1, 2, 3, 4]}
df = pd.DataFrame(dataset)
print(df)
# Out:
#    height  weight
# 0       2       1
# 1       3       2
# 2       4       3
# 3       5       4

# %%
scaler = StandardScaler()
x_scaler = scaler.fit_transform(df)
print(x_scaler)
# Out:
# [[-1.34164079 -1.34164079]
#  [-0.4472136  -0.4472136 ]
#  [ 0.4472136   0.4472136 ]
#  [ 1.34164079  1.34164079]]

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("\nPCA Result:")
print(X_pca)

print("\nExplained variance ratio:")
print(pca.explained_variance_ratio_)

print("Total variance:", pca.explained_variance_ratio_.sum())
# Out:
# PCA Result:
# [[-1.89736660e+00  2.45758343e-16]
#  [-6.32455532e-01 -4.56146509e-17]
#  [ 6.32455532e-01  4.56146509e-17]
#  [ 1.89736660e+00  2.15348576e-16]]
#
# Explained variance ratio:
# [1.00000000e+00 1.38666956e-32]
# Total variance: 1.0
